# %% [markdown]
# # 数据预处理

# %%
from tqdm import tqdm
import json
import numpy as np

# %% [markdown]
# ## 引入sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

countVectorizer = CountVectorizer(stop_words='english')
tfidfVectorizer = TfidfVectorizer(stop_words='english')

# %% [markdown]
# ## 生成词向量矩阵和label向量

# %%
with open('./exp1data/train_data.txt') as f:
    train_data_raw = f.read()
    f.close()

train_data_raw = [json.loads(data) for data in train_data_raw.strip().split('\n')]

text_num = len(train_data_raw)
texts, label = [], []

for data in tqdm(train_data_raw):
    texts.append(data['raw'])
    label.append(data['label'])

matrix = countVectorizer.fit_transform(texts)
vocab = countVectorizer.get_feature_names_out()

matrix = tfidfVectorizer.fit_transform(texts)
vocab = tfidfVectorizer.get_feature_names_out()

all_data = matrix.toarray()
all_label = np.array(label)
# Out:
# 100%|██████████| 8000/8000 [00:00<00:00, 1486946.38it/s]

# %% [markdown]
# ## 分割训练集和验证集

# %%
from sklearn.model_selection import train_test_split
train_data, val_data, train_label, val_label = train_test_split(all_data, all_label, test_size=0.2)

# %% [markdown]
# # 模型训练

# %% [markdown]
# ## 导入Pytorch包

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## Config

# %%
BATCH_SIZE = 64
PRINT = 10

# %% [markdown]
# ## 将ndarray数组转为tensor格式

# %%
train_dataset = TensorDataset(
    torch.FloatTensor(train_data),
    torch.LongTensor(train_label)
    )
loader_train = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

val_dataset = TensorDataset(
    torch.FloatTensor(val_data),
    torch.LongTensor(val_label)
    )
loader_val = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# ## 构造全连接神经网络FC(MLP)

# %%
class FC(nn.Module):
    def __init__(self, input_size, hidden_size, classes_num):
        super(FC, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, classes_num)
    
    # 不加激活默认RELU激活
    def forward(self, x):
        scores = self.fc1(x)
        scores = self.fc2(scores)
        return scores

# %% [markdown]
# ## 构造训练及验证函数

# %%
def val(loader_val, model):
    model.eval()
    cor, all = 0, 0
    for (x, y) in loader_val:
        all += len(y)
        scores = model(x)
        for idx, each in enumerate(scores):
            if y[idx] == np.argmax(each.detach().numpy()): 
                cor += 1

    acc = cor / all
    print('val acc: ', acc)

def train(model, loss_func, optim, loader_train, loader_val, epoch=1):
    for e in range(epoch):
        for idx, (x, y) in enumerate(loader_train):
            # switch to train mode
            model.train()
            scores = model(x)
            loss = loss_func(scores, y)

            optim.zero_grad()
            loss.backward()
            optim.step()
            
            if idx % PRINT == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, idx, loss.item()))
                if loader_val:
                    val(loader_val, model)
                print()

# %% [markdown]
# ## 训练模型
# 此处调参过程已省略，具体调参过程参照实验报告

# %%
lr = 9e-4
wd = 1e-4

model = FC(train_data.shape[1], int(np.sqrt(train_data.shape[1])), 10)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

train(model, loss_func, optimizer, loader_train, loader_val, 10)
# Out:
# Epoch 0, Iteration 0, loss = 2.3200
# val acc:  0.14
#
# Epoch 0, Iteration 10, loss = 2.2670
# val acc:  0.37375
#
# Epoch 0, Iteration 20, loss = 2.1944
# val acc:  0.679375
#
# Epoch 0, Iteration 30, loss = 2.1430
# val acc:  0.80625
#
# Epoch 0, Iteration 40, loss = 1.9872
# val acc:  0.861875
#
# Epoch 0, Iteration 50, loss = 1.8822
# val acc:  0.90125
#
# Epoch 0, Iteration 60, loss = 1.7530
# val acc:  0.921875
#
# Epoch 0, Iteration 70, loss = 1.5712
# val acc:  0.924375
#
# Epoch 0, Iteration 80, loss = 1.3943
# val acc:  0.92625
#
# Epoch 0, Iteration 90, loss = 1.2467
# val acc:  0.928125
#
# Epoch 1, Iteration 0, loss = 0.8322
# val acc:  0.931875
#
# Epoch 1, Iteration 10, loss = 0.6923
# val acc:  0.93375
#
# Epoch 1, Iteration 20, loss = 0.6645
# val acc:  0.943125
#
# Epoch 1, Iteration 30, loss = 0.5022
# val acc:  0.944375
#
# Epoch 1, Iteration 40, loss = 0.4547
# val acc:  0.94625
#
# Epoch 1, Iteration 50, loss = 0.3851
# val acc:  0.94875
#
# Epoch 1, Iteration 60, loss = 0.4530
# val acc:  0.95125
#
# Epoch 1, Iteration 70, loss = 0.3129
# val acc:  0.95125
#
# Epoch 1, Iteration 80, loss = 0.2645
# val acc:  0.9525
#
# Epoch 1, Iteration 90, loss = 0.3054
# val acc:  0.955625
#
# Epoch 2, Iteration 0, loss = 0.2391
# val acc:  0.955625
#
# Epoch 2, Iteration 10, loss = 0.1368
# val acc:  0.955
#
# Epoch 2, Iteration 20, loss = 0.1710
# val acc:  0.954375
#
# Epoch 2, Iteration 30, loss = 0.1567
# val acc:  0.95375
#
# Epoch 2, Iteration 40, loss = 0.1124
# val acc:  0.95375
#
# Epoch 2, Iteration 50, loss = 0.1347
# val acc:  0.954375
#
# Epoch 2, Iteration 60, loss = 0.1298
# val acc:  0.955625
#
# Epoch 2, Iteration 70, loss = 0.1337
# val acc:  0.9575
#
# Epoch 2, Iteration 80, loss = 0.1954
# val acc:  0.95875
#
# Epoch 2, Iteration 90, loss = 0.1737
# val acc:  0.9575
#
# Epoch 3, Iteration 0, loss = 0.0734
# val acc:  0.959375
#
# Epoch 3, Iteration 10, loss = 0.0968
# val acc:  0.960625
#
# Epoch 3, Iteration 20, loss = 0.0857
# val acc:  0.96
#
# Epoch 3, Iteration 30, loss = 0.0759
# val acc:  0.959375
#
# Epoch 3, Iteration 40, loss = 0.1010
# val acc:  0.960625
#
# Epoch 3, Iteration 50, loss = 0.0933
# val acc:  0.96125
#
# Epoch 3, Iteration 60, loss = 0.0732
# val acc:  0.959375
#
# Epoch 3, Iteration 70, loss = 0.0747
# val acc:  0.96
#
# Epoch 3, Iteration 80, loss = 0.0998
# val acc:  0.96
#
# Epoch 3, Iteration 90, loss = 0.0780
# val acc:  0.95875
#
# Epoch 4, Iteration 0, loss = 0.0472
# val acc:  0.96
#
# Epoch 4, Iteration 10, loss = 0.0412
# val acc:  0.959375
#
# Epoch 4, Iteration 20, loss = 0.0582
# val acc:  0.959375
#
# Epoch 4, Iteration 30, loss = 0.0398
# val acc:  0.96125
#
# Epoch 4, Iteration 40, loss = 0.0505
# val acc:  0.9625
#
# Epoch 4, Iteration 50, loss = 0.0524
# val acc:  0.960625
#
# Epoch 4, Iteration 60, loss = 0.0560
# val acc:  0.96125
#
# Epoch 4, Iteration 70, loss = 0.0537
# val acc:  0.96125
#
# Epoch 4, Iteration 80, loss = 0.0560
# val acc:  0.96
#
# Epoch 4, Iteration 90, loss = 0.0531
# val acc:  0.96
#
# Epoch 5, Iteration 0, loss = 0.0393
# val acc:  0.961875
#
# Epoch 5, Iteration 10, loss = 0.0330
# val acc:  0.961875
#
# Epoch 5, Iteration 20, loss = 0.0437
# val acc:  0.960625
#
# Epoch 5, Iteration 30, loss = 0.0383
# val acc:  0.96
#
# Epoch 5, Iteration 40, loss = 0.0491
# val acc:  0.959375
#
# Epoch 5, Iteration 50, loss = 0.0447
# val acc:  0.95875
#
# Epoch 5, Iteration 60, loss = 0.0454
# val acc:  0.959375
#
# Epoch 5, Iteration 70, loss = 0.0334
# val acc:  0.96
#
# Epoch 5, Iteration 80, loss = 0.0733
# val acc:  0.96125
#
# Epoch 5, Iteration 90, loss = 0.0432
# val acc:  0.960625
#
# Epoch 6, Iteration 0, loss = 0.0292
# val acc:  0.96125
#
# Epoch 6, Iteration 10, loss = 0.0313
# val acc:  0.96125
#
# Epoch 6, Iteration 20, loss = 0.0332
# val acc:  0.959375
#
# Epoch 6, Iteration 30, loss = 0.0265
# val acc:  0.96
#
# Epoch 6, Iteration 40, loss = 0.0323
# val acc:  0.96125
#
# Epoch 6, Iteration 50, loss = 0.0319
# val acc:  0.96
#
# Epoch 6, Iteration 60, loss = 0.0290
# val acc:  0.959375
#
# Epoch 6, Iteration 70, loss = 0.0411
# val acc:  0.960625
#
# Epoch 6, Iteration 80, loss = 0.0388
# val acc:  0.96125
#
# Epoch 6, Iteration 90, loss = 0.0411
# val acc:  0.960625
#
# Epoch 7, Iteration 0, loss = 0.0355
# val acc:  0.960625
#
# Epoch 7, Iteration 10, loss = 0.0248
# val acc:  0.96
#
# Epoch 7, Iteration 20, loss = 0.0252
# val acc:  0.96
#
# Epoch 7, Iteration 30, loss = 0.0357
# val acc:  0.960625
#
# Epoch 7, Iteration 40, loss = 0.0301
# val acc:  0.96
#
# Epoch 7, Iteration 50, loss = 0.0374
# val acc:  0.96
#
# Epoch 7, Iteration 60, loss = 0.0284
# val acc:  0.96
#
# Epoch 7, Iteration 70, loss = 0.0308
# val acc:  0.95875
#
# Epoch 7, Iteration 80, loss = 0.0349
# val acc:  0.96
#
# Epoch 7, Iteration 90, loss = 0.0540
# val acc:  0.959375
#
# Epoch 8, Iteration 0, loss = 0.0280
# val acc:  0.959375
#
# Epoch 8, Iteration 10, loss = 0.0247
# val acc:  0.960625
#
# Epoch 8, Iteration 20, loss = 0.0241
# val acc:  0.96
#
# Epoch 8, Iteration 30, loss = 0.0430
# val acc:  0.95875
#
# Epoch 8, Iteration 40, loss = 0.0332
# val acc:  0.95875
#
# Epoch 8, Iteration 50, loss = 0.0263
# val acc:  0.95875
#
# Epoch 8, Iteration 60, loss = 0.0238
# val acc:  0.956875
#
# Epoch 8, Iteration 70, loss = 0.0298
# val acc:  0.958125
#
# Epoch 8, Iteration 80, loss = 0.0392
# val acc:  0.95875
#
# Epoch 8, Iteration 90, loss = 0.0264
# val acc:  0.96
#
# Epoch 9, Iteration 0, loss = 0.0253
# val acc:  0.959375
#
# Epoch 9, Iteration 10, loss = 0.0273
# val acc:  0.959375
#
# Epoch 9, Iteration 20, loss = 0.0229
# val acc:  0.959375
#
# Epoch 9, Iteration 30, loss = 0.0259
# val acc:  0.96
#
# Epoch 9, Iteration 40, loss = 0.0270
# val acc:  0.96
#
# Epoch 9, Iteration 50, loss = 0.0340
# val acc:  0.9575
#
# Epoch 9, Iteration 60, loss = 0.0231
# val acc:  0.958125
#
# Epoch 9, Iteration 70, loss = 0.0284
# val acc:  0.958125
#
# Epoch 9, Iteration 80, loss = 0.0338
# val acc:  0.9575
#
# Epoch 9, Iteration 90, loss = 0.0405
# val acc:  0.958125

# %% [markdown]
# ## 使用全部数据训练模型

# %%
all_dataset = TensorDataset(
    torch.FloatTensor(all_data),
    torch.LongTensor(all_label)
    )
loader_all = DataLoader(all_dataset, batch_size=BATCH_SIZE, shuffle=True)

lr = 9e-4
wd = 1e-4

model = FC(train_data.shape[1], int(np.sqrt(train_data.shape[1])), 10)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

train(model, loss_func, optimizer, loader_all, [], 10)
# Out:
# Epoch 0, Iteration 0, loss = 2.3059
#
# Epoch 0, Iteration 10, loss = 2.2644
#
# Epoch 0, Iteration 20, loss = 2.2097
#
# Epoch 0, Iteration 30, loss = 2.1194
#
# Epoch 0, Iteration 40, loss = 1.9980
#
# Epoch 0, Iteration 50, loss = 1.9124
#
# Epoch 0, Iteration 60, loss = 1.7552
#
# Epoch 0, Iteration 70, loss = 1.5678
#
# Epoch 0, Iteration 80, loss = 1.3716
#
# Epoch 0, Iteration 90, loss = 1.2110
#
# Epoch 0, Iteration 100, loss = 0.9546
#
# Epoch 0, Iteration 110, loss = 0.8670
#
# Epoch 0, Iteration 120, loss = 0.7794
#
# Epoch 1, Iteration 0, loss = 0.5907
#
# Epoch 1, Iteration 10, loss = 0.5250
#
# Epoch 1, Iteration 20, loss = 0.4688
#
# Epoch 1, Iteration 30, loss = 0.3731
#
# Epoch 1, Iteration 40, loss = 0.3380
#
# Epoch 1, Iteration 50, loss = 0.3269
#
# Epoch 1, Iteration 60, loss = 0.3091
#
# Epoch 1, Iteration 70, loss = 0.3081
#
# Epoch 1, Iteration 80, loss = 0.2519
#
# Epoch 1, Iteration 90, loss = 0.2425
#
# Epoch 1, Iteration 100, loss = 0.2441
#
# Epoch 1, Iteration 110, loss = 0.2137
#
# Epoch 1, Iteration 120, loss = 0.1687
#
# Epoch 2, Iteration 0, loss = 0.1385
#
# Epoch 2, Iteration 10, loss = 0.1172
#
# Epoch 2, Iteration 20, loss = 0.1200
#
# Epoch 2, Iteration 30, loss = 0.1436
#
# Epoch 2, Iteration 40, loss = 0.1422
#
# Epoch 2, Iteration 50, loss = 0.1061
#
# Epoch 2, Iteration 60, loss = 0.0829
#
# Epoch 2, Iteration 70, loss = 0.0945
#
# Epoch 2, Iteration 80, loss = 0.1727
#
# Epoch 2, Iteration 90, loss = 0.1370
#
# Epoch 2, Iteration 100, loss = 0.1015
#
# Epoch 2, Iteration 110, loss = 0.1019
#
# Epoch 2, Iteration 120, loss = 0.0988
#
# Epoch 3, Iteration 0, loss = 0.0567
#
# Epoch 3, Iteration 10, loss = 0.0677
#
# Epoch 3, Iteration 20, loss = 0.0538
#
# Epoch 3, Iteration 30, loss = 0.0662
#
# Epoch 3, Iteration 40, loss = 0.0502
#
# Epoch 3, Iteration 50, loss = 0.0719
#
# Epoch 3, Iteration 60, loss = 0.0816
#
# Epoch 3, Iteration 70, loss = 0.0442
#
# Epoch 3, Iteration 80, loss = 0.0501
#
# Epoch 3, Iteration 90, loss = 0.0495
#
# Epoch 3, Iteration 100, loss = 0.0548
#
# Epoch 3, Iteration 110, loss = 0.0465
#
# Epoch 3, Iteration 120, loss = 0.0756
#
# Epoch 4, Iteration 0, loss = 0.0338
#
# Epoch 4, Iteration 10, loss = 0.0405
#
# Epoch 4, Iteration 20, loss = 0.0389
#
# Epoch 4, Iteration 30, loss = 0.0427
#
# Epoch 4, Iteration 40, loss = 0.0429
#
# Epoch 4, Iteration 50, loss = 0.0402
#
# Epoch 4, Iteration 60, loss = 0.0461
#
# Epoch 4, Iteration 70, loss = 0.0505
#
# Epoch 4, Iteration 80, loss = 0.0381
#
# Epoch 4, Iteration 90, loss = 0.0359
#
# Epoch 4, Iteration 100, loss = 0.0340
#
# Epoch 4, Iteration 110, loss = 0.0514
#
# Epoch 4, Iteration 120, loss = 0.0417
#
# Epoch 5, Iteration 0, loss = 0.0346
#
# Epoch 5, Iteration 10, loss = 0.0358
#
# Epoch 5, Iteration 20, loss = 0.0329
#
# Epoch 5, Iteration 30, loss = 0.0329
#
# Epoch 5, Iteration 40, loss = 0.0446
#
# Epoch 5, Iteration 50, loss = 0.0329
#
# Epoch 5, Iteration 60, loss = 0.0346
#
# Epoch 5, Iteration 70, loss = 0.0349
#
# Epoch 5, Iteration 80, loss = 0.0648
#
# Epoch 5, Iteration 90, loss = 0.0790
#
# Epoch 5, Iteration 100, loss = 0.0341
#
# Epoch 5, Iteration 110, loss = 0.0432
#
# Epoch 5, Iteration 120, loss = 0.0432
#
# Epoch 6, Iteration 0, loss = 0.0293
#
# Epoch 6, Iteration 10, loss = 0.0229
#
# Epoch 6, Iteration 20, loss = 0.0281
#
# Epoch 6, Iteration 30, loss = 0.0263
#
# Epoch 6, Iteration 40, loss = 0.0606
#
# Epoch 6, Iteration 50, loss = 0.0356
#
# Epoch 6, Iteration 60, loss = 0.0296
#
# Epoch 6, Iteration 70, loss = 0.0289
#
# Epoch 6, Iteration 80, loss = 0.0346
#
# Epoch 6, Iteration 90, loss = 0.0378
#
# Epoch 6, Iteration 100, loss = 0.0225
#
# Epoch 6, Iteration 110, loss = 0.0281
#
# Epoch 6, Iteration 120, loss = 0.0641
#
# Epoch 7, Iteration 0, loss = 0.0205
#
# Epoch 7, Iteration 10, loss = 0.0225
#
# Epoch 7, Iteration 20, loss = 0.0275
#
# Epoch 7, Iteration 30, loss = 0.0288
#
# Epoch 7, Iteration 40, loss = 0.0307
#
# Epoch 7, Iteration 50, loss = 0.0260
#
# Epoch 7, Iteration 60, loss = 0.0251
#
# Epoch 7, Iteration 70, loss = 0.0336
#
# Epoch 7, Iteration 80, loss = 0.0324
#
# Epoch 7, Iteration 90, loss = 0.0354
#
# Epoch 7, Iteration 100, loss = 0.0220
#
# Epoch 7, Iteration 110, loss = 0.0352
#
# Epoch 7, Iteration 120, loss = 0.0321
#
# Epoch 8, Iteration 0, loss = 0.0332
#
# Epoch 8, Iteration 10, loss = 0.0417
#
# Epoch 8, Iteration 20, loss = 0.0203
#
# Epoch 8, Iteration 30, loss = 0.0213
#
# Epoch 8, Iteration 40, loss = 0.0257
#
# Epoch 8, Iteration 50, loss = 0.0227
#
# Epoch 8, Iteration 60, loss = 0.0309
#
# Epoch 8, Iteration 70, loss = 0.0310
#
# Epoch 8, Iteration 80, loss = 0.0201
#
# Epoch 8, Iteration 90, loss = 0.0315
#
# Epoch 8, Iteration 100, loss = 0.0324
#
# Epoch 8, Iteration 110, loss = 0.0359
#
# Epoch 8, Iteration 120, loss = 0.0389
#
# Epoch 9, Iteration 0, loss = 0.0177
#
# Epoch 9, Iteration 10, loss = 0.0192
#
# Epoch 9, Iteration 20, loss = 0.0451
#
# Epoch 9, Iteration 30, loss = 0.0237
#
# Epoch 9, Iteration 40, loss = 0.0241
#
# Epoch 9, Iteration 50, loss = 0.0284
#
# Epoch 9, Iteration 60, loss = 0.0225
#
# Epoch 9, Iteration 70, loss = 0.0247
#
# Epoch 9, Iteration 80, loss = 0.0461
#
# Epoch 9, Iteration 90, loss = 0.0279
#
# Epoch 9, Iteration 100, loss = 0.0495
#
# Epoch 9, Iteration 110, loss = 0.0255
#
# Epoch 9, Iteration 120, loss = 0.0238

# %% [markdown]
# # 预测测试集

# %%
test_data = []
test_label = []
model.eval()

with open('./exp1data/test.txt') as testf:
    testf.readline()
    for line in testf.readlines():
        id, text = line.split(',', 1)
        test_data.append(text)
    
    # test_data = countVectorizer.transform(test_data)
    test_data = tfidfVectorizer.transform(test_data)

scores = model(torch.FloatTensor(test_data.toarray()))

for s in scores:
    test_label.append(np.argmax(s.detach().numpy()))

with open('./exp1data/mlpoutput.txt', 'w') as outputf:
    outputf.write('id, pred\n')
    for id, pred in enumerate(test_label):
        outputf.write('%d, %d\n' % (int(id), pred))
